# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
import imageio
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('dataset/sp1s_aa_train.csv', delimiter=";")
data.head()
# Out:
#    class   F3_1   F3_2   F3_3   F3_4   F3_5   F3_6   F3_7   F3_8   F3_9  ...  \
# 0    0.0   41.8   44.8   47.1   37.4   40.1   40.6   43.8   43.1   62.8  ...
# 1    1.0  132.0  137.0  148.0  137.1  153.1  143.1  145.1  140.0  143.1  ...
# 2    0.0   69.4   57.0   76.4   52.0   63.0   45.0   63.3   56.8   71.5  ...
# 3    1.0   53.2   52.5   46.9   51.1   45.1   52.9   57.3   69.1   66.6  ...
# 4    0.0   55.6   55.8   58.3   62.3   71.5   83.0   93.6   99.1   98.6  ...
#
#    O2_41  O2_42  O2_43  O2_44  O2_45  O2_46  O2_47  O2_48  O2_49  O2_50
# 0   40.1   43.0   46.5   46.3   43.6   36.7   40.7   30.7   40.6   33.1
# 1  -27.5  -24.5  -31.5  -43.1  -48.7  -53.0  -59.5  -44.6  -31.7  -19.1
# 2   11.9   22.4   22.0   38.9   26.1   18.6    0.2   15.9    2.2   22.3
# 3   34.4   31.1   31.0   14.9   31.0   20.8   18.0    4.4   11.7   14.1
# 4   26.9   23.0    5.6   12.4    8.3   16.8   14.5   27.4   16.4   23.9
#
# [5 rows x 1401 columns]

# %%
labels = [
    'left',
    'right'
]
eletrodes = ['F3', 'F1', 'Fz', 'F2', 'F4', 'FC5', 'FC3', 'FC1', 'FCz',
             'FC2', 'FC4', 'FC6', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4',
             'C6', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6',
             'O1', 'O2']

# %%
def split_eletrodes(data):
    lb = data[0]
    sign_eletrode = []
    index_1 = 1
    index_2 = 51

    for e in eletrodes:
        sign_eletrode.append(data[index_1:index_2])
        index_1 += 50
        index_2 += 50
    
    return lb, sign_eletrode

def plot_graph(lb, features, eletrode):
    title = labels[int(lb)]
    index_eletrode = eletrodes.index(eletrode)

    plt.clf()
    plt.title(eletrode + ' - ' + title)
    plt.plot(features[index_eletrode], linestyle="-", marker="x")
    plt.show()

# %%
cwt_features = []
label_list = []
widths = np.arange(1, 41)
indx_C4 = eletrodes.index('C4')
indx_C5 = eletrodes.index('C5')
indx_Cz = eletrodes.index('Cz')
cont = 0 
for row in data.iloc:
    lb, sign = split_eletrodes(row.to_numpy())
   
   
    cwtmatr_C5 = (signal.cwt(sign[indx_C5], signal.morlet, widths))/255.0
    
    img_stack = cwtmatr_C5
    
    img = np.zeros((np.array(img_stack).shape[0], np.array(img_stack).shape[1], 3 ))
    
    img[:,:,0] = img_stack
    img[:,:,1] = img_stack
    img[:,:,2] = img_stack
    
    
    label_list.append(int(lb))
    cwt_features.append(img)
    #imageio.imwrite('images/outfile'+str(cont)+'_'+str(int(lb))+'.png', np.vstack([cwtmatr_C4, cwtmatr_Cz, cwtmatr_C5]))
    cont += 1
# Out:
# C:\Users\arthu\AppData\Local\Temp\ipykernel_7008\4076460503.py:18: ComplexWarning: Casting complex values to real discards the imaginary part
#   img[:,:,0] = img_stack
# C:\Users\arthu\AppData\Local\Temp\ipykernel_7008\4076460503.py:19: ComplexWarning: Casting complex values to real discards the imaginary part
#   img[:,:,1] = img_stack
# C:\Users\arthu\AppData\Local\Temp\ipykernel_7008\4076460503.py:20: ComplexWarning: Casting complex values to real discards the imaginary part
#   img[:,:,2] = img_stack

# %%
print(len(cwt_features))
print(len(cwt_features[0]))
print(len(cwt_features[0][0]))
print(len(cwt_features[0][0][0]))
# Out:
# 316
# 40
# 50
# 3

# %%
# data 90x50
features_train = []
labels_train = []
features_test = []
labels_test = []

for i in range(len(cwt_features)):
    if(i < 80):
        features_test.append(cwt_features[i])
        labels_test.append(label_list[i])
    else:
        features_train.append(cwt_features[i])
        labels_train.append(label_list[i])

features_train = np.array(features_train).reshape((236, 40, 50, 3))
features_test = np.array(features_test).reshape((80, 40, 50, 3))

# %%
img_generator = tf.keras.preprocessing.image.ImageDataGenerator()
features_train = img_generator.flow(
    features_train,
    y=np.array(labels_train),
    batch_size=16,
    
    shuffle=True)
features_test = img_generator.flow(
    features_test,
    y=np.array(labels_test),
    batch_size=16,
    
    shuffle=True)

# %%
conv_base = tf.keras.applications.EfficientNetB3(
                  include_top=False,
                  input_shape=(40, 50, 3),
                  pooling='avg'
                  )

input_layer=tf.keras.Input(shape=(40,50,3))

x=conv_base(input_layer,training=True)

output=tf.keras.layers.Dense(units=1,activation='sigmoid')(x)
model_EffB3=tf.keras.Model(input_layer,output)
model_EffB3.compile(optimizer='adam',loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
#model_base.load('/models/model_EffB3_C5.h5')
history = model_EffB3.fit(features_train.x, features_train.y, epochs=30, 
                    validation_data=(features_test.x, features_test.y))

model_EffB3.save('./models/model_EffB3_C5.h5')
# Out:
# Epoch 1/30
# C:\Users\arthu\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\dispatch.py:1082: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 8/8 [==============================] - 35s 2s/step - loss: 0.8058 - accuracy: 0.5212 - val_loss: 1.0056 - val_accuracy: 0.5375
# Epoch 2/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.7508 - accuracy: 0.6229 - val_loss: 1.1745 - val_accuracy: 0.4625
# Epoch 3/30
# 8/8 [==============================] - 12s 2s/step - loss: 0.7312 - accuracy: 0.6737 - val_loss: 0.9932 - val_accuracy: 0.5375
# Epoch 4/30
# 8/8 [==============================] - 12s 2s/step - loss: 0.6608 - accuracy: 0.6780 - val_loss: 1.0826 - val_accuracy: 0.4625
# Epoch 5/30
# 8/8 [==============================] - 11s 1s/step - loss: 0.5895 - accuracy: 0.7161 - val_loss: 1.0946 - val_accuracy: 0.5375
# Epoch 6/30
# 8/8 [==============================] - 11s 1s/step - loss: 0.5043 - accuracy: 0.7585 - val_loss: 1.3400 - val_accuracy: 0.4875
# Epoch 7/30
# 8/8 [==============================] - 11s 1s/step - loss: 0.4062 - accuracy: 0.7797 - val_loss: 1.3442 - val_accuracy: 0.5375
# Epoch 8/30
# 8/8 [==============================] - 11s 1s/step - loss: 0.4847 - accuracy: 0.7500 - val_loss: 1.6002 - val_accuracy: 0.5125
# Epoch 9/30
# 8/8 [==============================] - 11s 1s/step - loss: 0.4928 - accuracy: 0.8178 - val_loss: 1.6404 - val_accuracy: 0.4125
# Epoch 10/30
# 8/8 [==============================] - 11s 1s/step - loss: 0.3343 - accuracy: 0.8686 - val_loss: 1.5864 - val_accuracy: 0.3500
# Epoch 11/30
# 8/8 [==============================] - 11s 1s/step - loss: 0.3598 - accuracy: 0.8729 - val_loss: 1.8737 - val_accuracy: 0.4125
# Epoch 12/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.4021 - accuracy: 0.8517 - val_loss: 1.7297 - val_accuracy: 0.4000
# Epoch 13/30
# 8/8 [==============================] - 11s 1s/step - loss: 0.3602 - accuracy: 0.8136 - val_loss: 1.3743 - val_accuracy: 0.4625
# Epoch 14/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.2784 - accuracy: 0.8559 - val_loss: 1.5467 - val_accuracy: 0.4375
# Epoch 15/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.3397 - accuracy: 0.8771 - val_loss: 1.9986 - val_accuracy: 0.4250
# Epoch 16/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.3222 - accuracy: 0.8602 - val_loss: 1.9488 - val_accuracy: 0.4125
# Epoch 17/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.2407 - accuracy: 0.8983 - val_loss: 1.7695 - val_accuracy: 0.4250
# Epoch 18/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.2689 - accuracy: 0.8856 - val_loss: 1.6056 - val_accuracy: 0.4750
# Epoch 19/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.2880 - accuracy: 0.8898 - val_loss: 1.6721 - val_accuracy: 0.4625
# Epoch 20/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.2742 - accuracy: 0.8729 - val_loss: 1.7173 - val_accuracy: 0.4250
# Epoch 21/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.2303 - accuracy: 0.9322 - val_loss: 1.8423 - val_accuracy: 0.4250
# Epoch 22/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.1870 - accuracy: 0.9322 - val_loss: 2.1621 - val_accuracy: 0.4500
# Epoch 23/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.2046 - accuracy: 0.9280 - val_loss: 2.0037 - val_accuracy: 0.5000
# Epoch 24/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.1765 - accuracy: 0.9195 - val_loss: 2.3694 - val_accuracy: 0.4000
# Epoch 25/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.1285 - accuracy: 0.9534 - val_loss: 2.4910 - val_accuracy: 0.5000
# Epoch 26/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.1455 - accuracy: 0.9364 - val_loss: 2.5236 - val_accuracy: 0.4625
# Epoch 27/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.1089 - accuracy: 0.9661 - val_loss: 2.8946 - val_accuracy: 0.4750
# Epoch 28/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.0719 - accuracy: 0.9661 - val_loss: 2.5951 - val_accuracy: 0.5500
# Epoch 29/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.0768 - accuracy: 0.9661 - val_loss: 3.0679 - val_accuracy: 0.4375
# Epoch 30/30
# 8/8 [==============================] - 10s 1s/step - loss: 0.0958 - accuracy: 0.9619 - val_loss: 3.0061 - val_accuracy: 0.4625
